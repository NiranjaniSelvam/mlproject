# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import seaborn as sns

# %%
df=pd.read_csv('/kaggle/input/road-accidents-data/dft-road-casualty-statistics-casualty-provisional-mid-year-unvalidated-2023.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62674 entries, 0 to 62673
# Data columns (total 19 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   collision_index                     62674 non-null  object
#  1   collision_year                      62674 non-null  int64
#  2   collision_reference                 62674 non-null  object
#  3   vehicle_reference                   62674 non-null  int64
#  4   casualty_reference                  62674 non-null  int64
#  5   casualty_class                      62674 non-null  int64
#  6   sex_of_casualty                     62674 non-null  int64
#  7   age_of_casualty                     62674 non-null  int64
#  8   age_band_of_casualty                62674 non-null  int64
#  9   casualty_severity                   62674 non-null  int64
#  10  pedestrian_location                 62674 non-null  int64
# ...

# %%
df.shape
# Out:
# (62674, 19)

# %%
df.head()
# Out:
#   collision_index  collision_year collision_reference  vehicle_reference  \
# 0   2023010419171            2023           010419171                  1
# 1   2023010419183            2023           010419183                  2
# 2   2023010419183            2023           010419183                  3
# 3   2023010419189            2023           010419189                  1
# 4   2023010419191            2023           010419191                  2
#
#    casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                   1               3                2               20
# 1                   1               1                1               25
# 2                   2               2                2               38
# 3                   1               1                1               50
# 4                   1               1                1               34
#
#    age_band_of_casualty  casualty_severity  pedestrian_location  \
# ...

# %%
df.tail()
# Out:
#       collision_index  collision_year collision_reference  vehicle_reference  \
# 62669   2023991365442            2023           991365442                  1
# 62670   2023991366101            2023           991366101                  1
# 62671   2023991366235            2023           991366235                  1
# 62672   2023991369054            2023           991369054                  2
# 62673   2023991369155            2023           991369155                  2
#
#        casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 62669                   1               1                1               32
# 62670                   1               3                2               30
# 62671                   1               3                2               50
# 62672                   1               1                1               36
# 62673                   1               1                1                8
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       collision_index  collision_year collision_reference  vehicle_reference  \
# 0       2023010419171            2023           010419171                  1
# 1       2023010419183            2023           010419183                  2
# 2       2023010419183            2023           010419183                  3
# 3       2023010419189            2023           010419189                  1
# 4       2023010419191            2023           010419191                  2
# ...               ...             ...                 ...                ...
# 62669   2023991365442            2023           991365442                  1
# 62670   2023991366101            2023           991366101                  1
# 62671   2023991366235            2023           991366235                  1
# 62672   2023991369054            2023           991369054                  2
# 62673   2023991369155            2023           991369155                  2
#
# ...

# %%
# Remove trailing whitespace from column names
df.columns = df.columns.str.strip()

# Then try accessing the columns again
selected_columns = df[['casualty_severity', 'car_passenger', 'lsoa_of_casualty']]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Assuming df is your DataFrame with relevant columns

# Remove trailing whitespace from column names
df.columns = df.columns.str.strip()

# Drop rows with missing values in specific columns
df = df[['casualty_severity', 'car_passenger', 'lsoa_of_casualty']].dropna()

# Count the occurrences of each value in a column
severity_counts = df['casualty_severity'].value_counts()

# Plot a bar chart using Matplotlib
plt.figure(figsize=(10, 6))
severity_counts.plot(kind='bar', color='skyblue')
plt.title('Casualty Severity Distribution')
plt.xlabel('Casualty Severity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# Plot a pie chart using Matplotlib
plt.figure(figsize=(8, 6))
plt.pie(severity_counts, labels=severity_counts.index, autopct='%1.1f%%', startangle=140, colors=['skyblue', 'lightcoral', 'lightgreen'])
plt.title('Casualty Severity Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.tight_layout()
plt.show()

# Plot a count plot using Seaborn
plt.figure(figsize=(10, 6))
sns.countplot(data=df, x='casualty_severity', palette='Set2')
plt.title('Casualty Severity Distribution')
plt.xlabel('Casualty Severity')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# Assuming df is your DataFrame with relevant columns

# Drop rows with missing values in specific columns
df = df[['casualty_severity', 'car_passenger', 'lsoa_of_casualty']].dropna()

# Encode categorical variables if needed
label_encoder = LabelEncoder()
df['car_passenger'] = label_encoder.fit_transform(df['car_passenger'])
df['lsoa_of_casualty'] = label_encoder.fit_transform(df['lsoa_of_casualty'])

# Split the data into features and target variable
X = df[['car_passenger', 'lsoa_of_casualty']]
y = df['casualty_severity']

# Split the data into training and testing sets (70% train, 30% test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Initialize the kNN classifier
k = 3  # choose the number of neighbors
knn_classifier = KNeighborsClassifier(n_neighbors=k)

# Train the classifier on the training data
knn_classifier.fit(X_train, y_train)

# Predict the labels for the test set
y_pred = knn_classifier.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# Print classification report and confusion matrix
print("\nClassification Report:")
print(classification_report(y_test, y_pred))

print("\nConfusion Matrix:")
print(confusion_matrix(y_test, y_pred))
# Out:
# Accuracy: 0.7438174759346913
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            1       0.02      0.01      0.02       201
#            2       0.23      0.10      0.14      3649
#            3       0.80      0.91      0.85     14953
#
#     accuracy                           0.74     18803
#    macro avg       0.35      0.34      0.34     18803
# weighted avg       0.68      0.74      0.70     18803
#
#
# Confusion Matrix:
# [[    3    23   175]
#  [   38   360  3251]
#  [  137  1193 13623]]
